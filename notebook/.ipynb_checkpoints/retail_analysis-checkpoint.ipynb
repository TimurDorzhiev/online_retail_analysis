# %% [markdown]
# #### 1. Импорт библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 2. Загрузка данных

# %%
df = pd.read_csv('/Users/timurdorziev/online_retail_analysis/data/O_Retail.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# #### 3. Первичный анализ

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# #### 4. Очистка данных

# %%
# Удалим пропуски
df = df.dropna()

# Удалим отмененные заказы (если InvoiceNo начинается с "С")
df = df[~df['InvoiceNo'].astype(str).str.startswith('C')]

# Удалим отрицательные значения
df = df[df['Quantity'] > 0]
df = df[df['UnitPrice'] > 0]

# %% [markdown]
# #### 5. Создание новых признаков

# %%
# Общая сумма покупки
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %% [markdown]
# #### 6. Анализ по странам

# %%
df['Country'].value_counts().head(10).plot(kind='bar')
plt.title('Топ-10 стран по количеству заказов')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# #### 7. Анализ по клиентам

# %%
df['CustomerID'].nunique()
df.groupby('CustomerID')['TotalPrice'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Топ-10 клиентов по объему покупок')
plt.show()

# %% [markdown]
# #### 8. Анализ по времени

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['Month'] = df['InvoiceDate'].dt.month
df.groupby('Month')['TotalPrice'].sum().plot(kind = 'line')
plt.title('Динамика продаж по месяцам')
plt.ylabel('Сумма')
plt.show()
